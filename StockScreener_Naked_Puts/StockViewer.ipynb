# %%
import pandas as pd

# %%
file_name = 'naked_puts_results.csv'
file_name2 = 'naked_puts_results2.csv'

# Read the File and turn it into a Pandas DataFrame
df = pd.read_csv(file_name)
df2 = pd.read_csv(file_name2)

# %% [markdown]
# ### Dataframe unsorted and filtered

# %%
df
# Out:
#      Weeks Ahead Expiration Date   ETF  Stock Price  lastPrice   bid   ask  \
# 0              0      2023-08-25   AMC         2.55       0.01  0.01  0.02
# 1              0      2023-08-25  SOFI         8.15       0.02  0.01  0.02
# 2              0      2023-08-25  SOFI         8.15       0.12  0.11  0.12
# 3              0      2023-08-25  PLUG         8.43       0.07  0.07  0.08
# 4              0      2023-08-25   GPS         9.57       0.06  0.06  0.07
# ..           ...             ...   ...          ...        ...   ...   ...
# 180            1      2023-09-01   MPW         6.77       0.04  0.02  0.04
# 181            1      2023-09-01  JBLU         6.20       0.03  0.02  0.03
# 182            1      2023-09-01  CHPT         7.02       0.02  0.02  0.03
# 183            1      2023-09-01  PLUG         8.43       0.02  0.01  0.02
# 184            1      2023-09-01   PBR        13.52       0.29  0.26  0.30
#
#      strike  ROI (%)  OTM (%)   volume  openInterest
# ...

# %% [markdown]
# ### Dataframe filtered

# %%
df2
# Out:
#     Weeks Ahead Expiration Date   ETF  Stock Price  lastPrice   bid   ask  \
# 0             0      2023-08-25   AMC         2.55       0.01  0.01  0.02
# 1             0      2023-08-25  SNDL         1.73       0.02  0.01  0.02
# 2             0      2023-08-25  OPEN         3.20       0.03  0.02  0.04
# 3             0      2023-08-25  PSNY         3.59       0.07  0.04  0.08
# 4             0      2023-08-25  LABU         4.81       0.04  0.04  0.05
# 5             0      2023-08-25  PTON         6.99       0.04  0.03  0.04
# 6             0      2023-08-25  UWMC         5.56       0.10  0.05  0.10
# 7             0      2023-08-25  LAZR         5.79       0.05  0.05  0.06
# 8             0      2023-08-25  PTON         6.99       0.07  0.07  0.08
# 9             1      2023-09-01   AMC         2.55       0.02  0.02  0.03
# 10            1      2023-09-01  PSNY         3.59       0.09  0.04  0.06
# 11            1      2023-09-01  OPEN         3.20       0.09  0.07  0.11
# ...
