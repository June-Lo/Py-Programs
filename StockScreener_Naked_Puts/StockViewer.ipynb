# %%
import pandas as pd

# %%
file_name = 'naked_puts_results.csv'
file_name2 = 'naked_puts_results2.csv'
file_name3 = 'firstFridayEnd.txt'
# Read the File and turn it into a Pandas DataFrame
df = pd.read_csv(file_name)
df2 = pd.read_csv(file_name2)

# Read the txt file and print it
with open(file_name3, 'r') as file:
    print(file.read())
# Out:
# 2023-08-25

# %% [markdown]
# ### Dataframe unsorted and filtered

# %%
df
# Out:
#      Weeks Ahead Expiration Date   ETF  Stock Price  lastPrice   bid   ask  \
# 0              0      2023-08-25  OPEN         3.40       0.02  0.01  0.02
# 1              0      2023-08-25  PSNY         3.68       0.04  0.01  0.03
# 2              0      2023-08-25  SIRI         4.16       0.03  0.02  0.03
# 3              0      2023-08-25    IQ         4.59       0.06  0.04  0.08
# 4              0      2023-08-25    BB         4.61       0.05  0.03  0.04
# ..           ...             ...   ...          ...        ...   ...   ...
# 171            1      2023-09-01   PBR        14.55       0.04  0.03  0.04
# 172            1      2023-09-01   PBR        14.55       0.08  0.06  0.07
# 173            1      2023-09-01   PBR        14.55       0.16  0.15  0.16
# 174            1      2023-09-01   PBR        14.55       0.34  0.33  0.34
# 175            1      2023-09-01   PAA        15.34       0.05  0.05  0.10
#
#      strike  ROI (%)  OTM (%)  volume  openInterest
# 0       3.0     0.33    11.76   347.0        1718.0
# 1       3.5     0.29     4.89     4.0        1132.0
# 2       4.0     0.50     3.85    47.0        2452.0
# 3       4.5     0.90     1.96   655.0        2883.0
# 4       4.5     0.67     2.39    62.0         930.0
# ..      ...      ...      ...     ...           ...
# 171    13.0     0.23    10.65    49.0        1166.0
# 172    13.5     0.45     7.22   976.0        1165.0
# 173    14.0     1.08     3.78    81.0         843.0
# 174    14.5     2.33     0.34  1179.0          15.0
# 175    15.0     0.33     2.22     1.0           6.0
#
# [176 rows x 12 columns]

# %% [markdown]
# ### Dataframe filtered

# %%
df2.head(30)
# Out:
#     Weeks Ahead Expiration Date   ETF  Stock Price  lastPrice   bid   ask  \
# 0             1      2023-09-01    HL         4.47       0.03  0.02  0.03
# 1             1      2023-09-01  LABU         4.96       0.03  0.02  0.03
# 2             1      2023-09-01  PTON         5.30       0.02  0.02  0.03
# 3             1      2023-09-01    QS         6.78       0.03  0.03  0.04
# 4             1      2023-09-01  SNDL         1.72       0.02  0.01  0.03
# 5             1      2023-09-01  PSNY         3.68       0.04  0.02  0.04
# 6             1      2023-09-01  CHPT         7.12       0.04  0.04  0.05
# 7             1      2023-09-01   MPW         6.91       0.04  0.04  0.06
# 8             1      2023-09-01   TAL         6.70       0.07  0.04  0.05
# 9             1      2023-09-01   UNG         6.64       0.05  0.04  0.05
# 10            1      2023-09-01  DISH         6.36       0.04  0.04  0.05
# 11            1      2023-09-01  LCID         6.09       0.05  0.05  0.06
# 12            1      2023-09-01  RKLB         5.98       0.05  0.05  0.10
# 13            1      2023-09-01  JBLU         6.21       0.06  0.06  0.07
# 14            1      2023-09-01  OPEN         3.41       0.04  0.04  0.05
# 15            1      2023-09-01  PTON         5.30       0.07  0.06  0.07
# 16            1      2023-09-01  LABU         4.96       0.07  0.07  0.08
# 17            1      2023-09-01  LAZR         5.81       0.10  0.10  0.12
# 18            1      2023-09-01  NKLA         1.33       0.03  0.02  0.03
# 19            1      2023-09-01  SIRI         4.16       0.08  0.08  0.09
# 20            1      2023-09-01  DISH         6.36       0.13  0.12  0.14
# 21            1      2023-09-01    BB         4.61       0.11  0.10  0.11
# 22            1      2023-09-01    IQ         4.59       0.13  0.10  0.14
# 23            1      2023-09-01  LCID         6.09       0.19  0.18  0.19
# 24            1      2023-09-01  PTON         5.30       0.17  0.17  0.18
# 25            1      2023-09-01  PSNY         3.68       0.14  0.13  0.15
#
#     strike  ROI (%)  OTM (%)  volume  openInterest
# 0      4.0     0.50    10.51    17.0         188.0
# 1      4.0     0.50    19.35   236.0        1153.0
# 2      4.0     0.50    24.53   240.0          99.0
# 3      6.0     0.50    11.50     1.0        1171.0
# 4      1.5     0.67    12.79     6.0         568.0
# 5      3.0     0.67    18.48     2.0         314.0
# 6      6.0     0.67    15.73     2.0        4147.0
# 7      6.0     0.67    13.17   404.0        1339.0
# 8      6.0     0.67    10.45    24.0         127.0
# 9      6.0     0.67     9.64    66.0        2958.0
# 10     5.5     0.73    13.52     3.0          80.0
# 11     5.5     0.92     9.69   153.0        1249.0
# 12     5.5     0.92     8.03    71.0         130.0
# 13     6.0     1.01     3.38    51.0         398.0
# 14     3.0     1.35    12.02   166.0         596.0
# 15     4.5     1.35    15.09   471.0         208.0
# 16     4.5     1.58     9.27   405.0        3298.0
# 17     5.5     1.85     5.34    50.0         347.0
# 18     1.0     2.04    24.81   140.0        3549.0
# 19     4.0     2.04     3.85   298.0        2568.0
# 20     6.0     2.04     5.66    35.0         617.0
# 21     4.5     2.27     2.39    24.0         891.0
# 22     4.5     2.27     1.96    57.0          74.0
# 23     6.0     3.09     1.48   790.0        3700.0
# 24     5.0     3.52     5.66  1967.0         470.0
# 25     3.5     3.86     4.89     6.0         133.0
